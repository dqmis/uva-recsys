# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_parquet('../data/ebnerd_large/train/behaviors.parquet')

# %%
df
# Out:
#           impression_id  article_id     impression_time  read_time  \
# 0                 47727         NaN 2023-05-21 21:35:07       20.0
# 1                 47731         NaN 2023-05-21 21:32:33       13.0
# 2                 47736         NaN 2023-05-21 21:33:32       17.0
# 3                 47737         NaN 2023-05-21 21:38:17       27.0
# 4                 47740         NaN 2023-05-21 21:36:02       48.0
# ...                 ...         ...                 ...        ...
# 12063885      580100982         NaN 2023-05-18 10:27:05        9.0
# 12063886      580100984         NaN 2023-05-18 10:30:39       13.0
# 12063887      580100987         NaN 2023-05-18 10:27:28       13.0
# 12063888      580100996         NaN 2023-05-18 10:08:18       35.0
# 12063889      580101002         NaN 2023-05-18 10:29:10       28.0
#
#           scroll_percentage  device_type  \
# 0                       NaN            1
# 1                       NaN            1
# ...

# %%
df_hist
# Out:
#         user_id                              impression_time_fixed  \
# 0         10029  [2023-04-28T06:16:57.000000, 2023-04-28T06:17:...
# 1         10033  [2023-04-27T11:11:32.000000, 2023-04-27T11:12:...
# 2         10034  [2023-04-30T09:46:57.000000, 2023-04-30T09:47:...
# 3         10041  [2023-04-27T15:15:28.000000, 2023-04-27T15:16:...
# 4         10103  [2023-04-27T15:37:35.000000, 2023-04-27T15:38:...
# ...         ...                                                ...
# 788085  1802030  [2023-05-13T16:20:53.000000, 2023-05-13T16:21:...
# 788086  2146107  [2023-05-10T21:44:01.000000, 2023-05-10T21:46:...
# 788087  1200613  [2023-04-30T05:24:43.000000, 2023-04-30T05:25:...
# 788088  1375724  [2023-05-10T12:25:50.000000, 2023-05-10T12:26:...
# 788089  1541617  [2023-05-08T07:31:13.000000, 2023-05-08T07:33:...
#
#                                   scroll_percentage_fixed  \
# 0       [23.0, 69.0, 27.0, nan, 47.0, 38.0, 100.0, 12....
# ...

# %%
# get count of unique user ids
df['user_id'].nunique()
# Out:
# 788090

# %%
plt.hist(df.groupby(['user_id']).count()['impression_id'].values, bins=100)
# Out:
# (array([2.04351e+05, 8.77160e+04, 9.50070e+04, 4.81730e+04, 5.78070e+04,
#         3.20100e+04, 4.06970e+04, 2.30140e+04, 2.95830e+04, 1.70730e+04,
#         2.23960e+04, 1.28710e+04, 1.68760e+04, 9.83300e+03, 1.29920e+04,
#         7.53400e+03, 1.00310e+04, 6.01600e+03, 7.69100e+03, 4.57300e+03,
#         6.08400e+03, 3.49700e+03, 4.68400e+03, 2.85100e+03, 3.56400e+03,
#         2.06500e+03, 2.80300e+03, 1.58800e+03, 2.25600e+03, 1.28200e+03,
#         1.64100e+03, 9.57000e+02, 1.26800e+03, 7.90000e+02, 1.01700e+03,
#         5.57000e+02, 7.51000e+02, 4.47000e+02, 6.06000e+02, 3.11000e+02,
#         4.58000e+02, 2.44000e+02, 3.21000e+02, 1.90000e+02, 2.23000e+02,
#         1.65000e+02, 1.97000e+02, 1.07000e+02, 1.30000e+02, 7.20000e+01,
#         7.80000e+01, 1.05000e+02, 5.90000e+01, 8.10000e+01, 4.20000e+01,
#         3.90000e+01, 2.40000e+01, 4.40000e+01, 2.70000e+01, 3.50000e+01,
#         1.70000e+01, 2.30000e+01, 1.20000e+01, 2.40000e+01, 8.00000e+00,
# ...

# %%
df.loc[df["article_id"].isnull()].count() / df.count()
# Out:
# impression_id             0.701103
# article_id                0.000000
# impression_time           0.701103
# read_time                 0.701103
# scroll_percentage         0.006553
# device_type               0.701103
# article_ids_inview        0.701103
# article_ids_clicked       0.701103
# user_id                   0.701103
# is_sso_user               0.701103
# gender                    0.689482
# postcode                  0.671369
# age                       0.675523
# is_subscriber             0.701103
# session_id                0.701103
# next_read_time            0.706772
# next_scroll_percentage    0.706607
# dtype: float64

# %%
set([i[0] for i in df["article_ids_clicked"].values.tolist()])
# Out:
# {9224194,
#  9428994,
#  9748484,
#  9682949,
#  9723906,
#  9306121,
#  9756683,
#  9773070,
#  8994831,
#  9068560,
#  9674767,
#  9568274,
#  9486351,
#  9773078,
#  9707542,
#  9773083,
#  9773084,
#  9494556,
#  9445412,
#  9740324,
#  9666599,
#  9625641,
#  9740330,
#  9412651,
#  9773102,
#  9764916,
#  9756733,
#  9527358,
#  9707583,
#  9257024,
#  9560129,
#  9699394,
#  9592898,
#  9674821,
#  9551946,
#  9560140,
#  9388110,
#  9052240,
#  9773137,
#  9699417,
#  9642075,
#  9388123,
#  9748574,
#  9748576,
#  9625700,
#  9470054,
#  9748582,
#  9625707,
#  9511021,
#  9756782,
#  9756784,
#  9756785,
#  9764978,
#  9363570,
#  9773172,
#  9756788,
#  9674870,
#  9666682,
#  9494650,
#  9191546,
#  9576570,
#  9470078,
#  9764986,
#  9715840,
#  9158780,
#  9764994,
#  9773188,
#  9470084,
#  9748614,
#  9289867,
#  9773199,
#  9592976,
#  9773203,
#  8020115,
#  9486486,
#  8380569,
#  9773210,
#  9298077,
#  9592991,
#  9756835,
#  9625764,
#  9707685,
#  9633961,
# ...

# %%
plt.boxplot(df.groupby(['user_id']).count()['impression_id'].values)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x11fc29b90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x11fc2ab10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x11fc29250>],
#  'medians': [<matplotlib.lines.Line2D at 0x11fc2bdd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x11fc38710>],
#  'means': []}

# %%
df.groupby(['user_id']).count()['impression_id'].values.min()
# Out:
# 1

# %%
df.groupby(['user_id']).count()['impression_id'].values.max()
# Out:
# 155

# %%
plt.hist(df.groupby(['user_id', 'session_id']).count()['impression_id'].values, bins=50)
# Out:
# (array([4.853031e+06, 6.491530e+05, 3.269230e+05, 2.682470e+05,
#         5.379500e+04, 3.049500e+04, 2.831500e+04, 6.493000e+03,
#         4.037000e+03, 2.542000e+03, 2.581000e+03, 6.720000e+02,
#         4.150000e+02, 4.500000e+02, 1.110000e+02, 6.200000e+01,
#         8.200000e+01, 1.500000e+01, 5.000000e+00, 1.100000e+01,
#         1.100000e+01, 5.000000e+00, 0.000000e+00, 1.000000e+00,
#         0.000000e+00, 0.000000e+00, 2.000000e+00, 2.000000e+00,
#         0.000000e+00, 0.000000e+00, 1.000000e+00, 2.000000e+00,
#         1.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         1.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         1.000000e+00, 0.000000e+00, 1.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 1.000000e+00]),
#  array([ 1. ,  2.3,  3.6,  4.9,  6.2,  7.5,  8.8, 10.1, 11.4, 12.7, 14. ,
#         15.3, 16.6, 17.9, 19.2, 20.5, 21.8, 23.1, 24.4, 25.7, 27. , 28.3,
# ...

# %%
df_hist = pd.read_parquet('../data/ebnerd_large/train/history.parquet')

# %%
a = []
for i in df_hist["article_id_fixed"].values.tolist():
    a.extend(i)

# %%
len(set(a))
# Out:
# 69140

# %%
df_hist["article_id_fixed"].apply(lambda x: len(x)).hist(bins=50)
# Out:
# <Axes: >

# %%
with open("../data/predictions_large_random/predictions.txt", "r") as f:
    lines = f.readlines()

# %%
lines
# Out:
# ['6451339 [8,1,6,7,4,2,9,5,3]\n',
#  '6451363 [5,4,3,7,6,8,1,2]\n',
#  '6451382 [1,5,3,4,2]\n',
#  '6451383 [7,6,8,9,3,4,2,11,10,1,5]\n',
#  '6451385 [5,3,2,4,7,6,1]\n',
#  '6451411 [9,1,8,3,4,6,2,7,5]\n',
#  '6451412 [2,5,6,7,8,3,4,1]\n',
#  '6451423 [28,4,26,9,10,32,1,29,3,30,6,33,25,2,18,22,27,8,15,24,17,20,31,7,21,13,12,16,5,19,14,23,11]\n',
#  '6451425 [3,1,6,2,5,4]\n',
#  '6451426 [3,5,2,4,1]\n',
#  '6451427 [1,3,5,2,6,7,4]\n',
#  '6451430 [8,7,1,5,6,4,3,2]\n',
#  '6451431 [6,1,3,12,2,13,9,5,11,4,14,8,10,7]\n',
#  '6451432 [5,3,8,11,10,13,17,15,16,12,7,9,6,1,14,2,18,4]\n',
#  '6451435 [10,1,3,6,12,4,9,11,5,2,7,8]\n',
#  '6451467 [2,3,4,1,5,6,7]\n',
#  '6451468 [6,3,4,5,7,2,9,1,8]\n',
#  '6451473 [5,8,4,6,3,1,10,2,7,9]\n',
#  '6451485 [1,5,2,4,3]\n',
#  '6451493 [1,5,7,16,11,22,21,19,12,3,18,6,8,9,17,4,20,15,10,2,13,14]\n',
#  '6451498 [1,4,3,5,2]\n',
#  '6451501 [2,3,13,5,1,9,6,7,15,18,17,10,8,20,16,19,14,4,11,21,12]\n',
#  '6451506 [3,2,4,5,1]\n',
# ...

# %%
test=pd.read_parquet('../data/ebnerd_testset/ebnerd_testset/test/behaviors.parquet')

# %%
test
# Out:
#           impression_id     impression_time  read_time  scroll_percentage  \
# 0               6451339 2023-06-05 15:02:49        8.0                NaN
# 1               6451363 2023-06-05 15:03:56       20.0                NaN
# 2               6451382 2023-06-05 15:25:53        9.0                NaN
# 3               6451383 2023-06-05 15:26:35       14.0                NaN
# 4               6451385 2023-06-05 15:26:14        8.0                NaN
# ...                 ...                 ...        ...                ...
# 13536705              0 2023-06-01 07:00:01        0.0                NaN
# 13536706              0 2023-06-01 07:00:01        0.0                NaN
# 13536707              0 2023-06-01 07:00:01        0.0                NaN
# 13536708              0 2023-06-01 07:00:01        0.0                NaN
# 13536709              0 2023-06-01 07:00:01        0.0                NaN
#
#           device_type                                 article_ids_inview  \
# ...
